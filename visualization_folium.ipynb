# %% [markdown]
# # GeoData Visualization - Folium
# This is a demo version showcasing the utilization of the Python library called Folium for geodata visualization. With Folium, you can create interactive maps to convey spatial information. This demonstration provides a glimpse into the features of Folium. For the fully developed version, please refer to the complete implementation available at the Library Digital Scholarship Repository at: https://dsprojects.lib.cuhk.edu.hk/en/projects/heading-analysis-machine-learning-hongkong-news/tabloid-hknews-geodata-visualization/

# %%
# !pip install -q pandas
# !pip install -q folium

# %%
import pandas as pd
import folium
import requests

# %%
# Collect data from the Chinese University of Hong Kong Research Data Repository
frame = 'https://researchdata.cuhk.edu.hk/api/access/datafile/510?format=original&gbrecs=true'
item = 'https://researchdata.cuhk.edu.hk/api/access/datafile/509?format=original&gbrecs=true'

# Change data format to dictionary
frame_df = requests.get(frame)
frame_df = pd.read_excel(frame_df.content)
frame_dict = frame_df.to_dict(orient='index')

item_df = requests.get(item)
item_df = pd.read_excel(item_df.content)
item_dict = item_df.to_dict(orient='index')

# %%
frame_df.head()
# Out:
#          Place                                     formatted_name        lat  \
# 0       Sittwe                            Sittwe, Myanmar (Burma)  20.152766
# 1      Dandong                           Dandong, Liaoning, China  39.999800
# 2      Rakhine                           Rakhine, Myanmar (Burma)  20.104082
# 3   Balikpapan  Balikpapan, Balikpapan City, East Kalimantan, ...  -1.237927
# 4  West Bengal                                 West Bengal, India  24.374074
#
#           lng components_name
# 0   92.867686          Sittwe
# 1  124.356010         Dandong
# 2   93.581269         Rakhine
# 3  116.852853      Balikpapan
# 4   87.851138     West Bengal

# %%
item_df.head()
# Out:
#    Unnamed: 0        Place  year  month  day  \
# 0           0     Caucasus  1942      7   29
# 1           1  Afghanistan  1942      7   29
# 2           2    Hong Kong  1942      7   30
# 3           3    Hong Kong  1942      7   30
# 4           4        Egypt  1942      7   30
#
#                                                title      pid
# 0  GERMAN TROOPS NOW ENTERING THE CAUCASUS Big Ba...  2624891
# 1              New Minister Appointed To Afghanistan  2624891
# 2  GOVERNOR SURVEYS HONGKONG PROBLEMS Receives Co...  2625337
# 3                         TYPHOON THREAT TO HONGKONG  2625337
# 4                        British Withdrawal In Egypt  2625337

# %%
# Created a map using Folium
fmap = folium.Map(location=[0, 0], zoom_start=3)

for place in frame_dict:
    name = frame_dict[place]['components_name']
    formatted_name = frame_dict[place]['formatted_name']
    lat = frame_dict[place]['lat']
    lng = frame_dict[place]['lng']

    item_content = ''
    for _ in item_dict:
        title_place = item_dict[_]['Place']

        if title_place == name:
            year = item_dict[_]['year']
            month = item_dict[_]['month']
            day = item_dict[_]['day']
            title = item_dict[_]['title']
            pid = item_dict[_]['pid']

            item_content += f'<p>{str(month)}/{str(day)}/{year}<a href="https://repository.lib.cuhk.edu.hk/en/islandora/object/cuhk%3A{pid}">{title}</a></p>'

    folium.Marker(location= [lat, lng],
                  popup= folium.Popup(html=f'<h1>{formatted_name}</h1>{item_content}', max_width=1000),
                  icon= folium.Icon()).add_to(fmap)

# %%
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_39ad36a11be77056cd75a8f37845df01 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_39ad36a11be77056cd75a8f37845df01&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_39ad36a11be77056cd75a8f37845df01 = L.map(
#                 &quot;map_39ad36a11be77056cd75a8f37845df01&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c7f899a27c8a5f8874c9f324ca5712a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_39ad36a11be77056cd75a8f37845df01);
#
#
#             var marker_d1211d6d547a930344380d87cda79eb5 = L.marker(
#                 [20.1527657, 92.86768610000001],
#                 {}
#             ).addTo(map_39ad36a11be77056cd75a8f37845df01);
#
#
#             var icon_97f9834875083fbe56d969d618b9cf95 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d1211d6d547a930344380d87cda79eb5.setIcon(icon_97f9834875083fbe56d969d618b9cf95);
#
#
#         var popup_5cea4af82ef29e606b9bf10751dbfa16 = L.popup({&quot;maxWidth&quot;: 1000});
#
#
#             var html_bf6962e3d9cc2ca18da29051aedcb506 = $(`&lt;div id=&quot;html_bf6962e3d9cc2ca18da29051aedcb506&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h1&gt;Sittwe, Myanmar (Burma)&lt;/h1&gt;&lt;p&gt;9/12/1942&lt;a href=&quot;https://repository.lib.cuhk.edu.hk/en/islandora/object/cuhk%3A2625846&quot;&gt;Abortive Enemy Raid On Akyab&lt;/a&gt;&lt;/p&gt;&lt;p&gt;3/3/1943&lt;a href=&quot;https://repository.lib.cuhk.edu.hk/en/islandora/object/cuhk%3A2625785&quot;&gt;Enemy Raiders Routed In Duel North Of Akyab&lt;/a&gt;&lt;/p&gt;&lt;p&gt;3/10/1943&lt;a href=&quot;https://repository.lib.cuhk.edu.hk/en/islandora/object/cuhk%3A2625372&quot;&gt;ABORTIVE RAID ON AKYAB ISLAND British Pay Heavily In Burma Sally&lt;/a&gt;&lt;/p&gt;&lt;p&gt;4/15/1943&lt;a href=&quot;https://repository.lib.cuhk.edu.hk/en/islandora/object/cuhk%3A2625150&quot;&gt;COMPOSITE WAR RESULTS OF AKYAB OPERATIONS&lt;/a&gt;&lt;/p&gt;&lt;p&gt;4/16/1943&lt;a href=&quot;https://repository.lib.cuhk.edu.hk/en/islandora/object/cuhk%3A2623746&quot;&gt;ATTEMPT TO TAKE AKYAB FRUSTRATED Imperial Forces Keep British And Indian Soldiers At Bay&lt;/a&gt;&lt;/p&gt;&lt;/div&gt;`)[0];
#             popup_5cea4af82ef29e606b9bf10751dbfa16.setContent(html_bf6962e3d9cc2ca18da29051aedcb506);
#
#
#         marker_d1211d6d547a930344380d87cda79eb5.bindPopup(popup_5cea4af82ef29e606b9bf10751dbfa16)
#         ;
#
#
#
#
#             var marker_709edbd773868a6123ee267d92ebd1a4 = L.marker(
#                 [39.9997999, 124.35601],
#                 {}
#             ).addTo(map_39ad36a11be77056cd75a8f37845df01);
#
#
#             var icon_213626a89eaab461812f48c5ede59ae1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_709edbd773868a6123ee267d92ebd1a4.setIcon(icon_213626a89eaab461812f48c5ede59ae1);
#
#
#         var popup_5a210bd6077d28a8637c2d729766c912 = L.popup({&quot;maxWidth&quot;: 1000});
#
#
#             var html_f7cd94a540f8c0e4ba9c8b0df17e0dba = $(`&lt;div id=&quot;html_f7cd94a540f8c0e4ba9c8b0df17e0dba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h1&gt;Dandong, Liaoning, China&lt;/h1&gt;&lt;p&gt;5/3/1943&lt;a href=&quot;https://repository.lib.cuhk.edu.hk/en/islandora/object/cuhk%3A2625121&quot;&gt;Emperor Of Manchoukuo Goes On Tour To Pay Visit To Antung Province&lt;/a&gt;&lt;/p&gt;&lt;p&gt;5/5/1943&lt;a href=&quot;https://repository.lib.cuhk.edu.hk/en/islandora/object/cuhk%3A2626033&quot;&gt;Emperor Of Manchoukuo In Antung Great Welcome By All Citizens&lt;/a&gt;&lt;/p&gt;&lt;p&gt;5/6/1943&lt;a href=&quot;https://repository.lib.cuhk.edu.hk/en/islandora/object/cuhk%3A2625523&quot;&gt;Manchoukuo Emperor&#x27;s Inspection Many Places In Antung Visited&lt;/a&gt;&lt;/p&gt;&lt;/div&gt;`)[0];
#             popup_5a210bd6077d28a8637c2d729766c912.setContent(html_f7cd94a540f8c0e4ba9c8b0df17e0dba);
#
#
#         marker_709edbd773868a6123ee267d92ebd1a4.bindPopup(popup_5a210bd6077d28a8637c2d729766c912)
#         ;
#
#
#
#
#             var marker_e4a5bd88d7226fe95f08b7f41aa936ef = L.marker(
#                 [20.1040818, 93.5812692],
#                 {}
#             ).addTo(map_39ad36a11be77056cd75a8f37845df01);
#
#
#             var icon_7b27eb03823708c979e946d9e3a108f2
